# %%
import sympy as sp

# %%
sqrt(8)

# %%
import math

# %%
math.sqrt(8)

# %%
sqrt(25)

# %%
pi

# %%
math.pi

# %%
x,y=sp.symbols('x y'
)

# %%
expr=x+2*y

# %%
expr

# %%
x*expr

# %%
factor(expand(x*expr))

# %%
limit(sin(x)/x,x,0)

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np
X=np.arange(-100,100,0.001)
plot(np.sin(X)/X)

# %%
diff(sin(x)*exp(x),x)

# %%
integrate(sin(x**2),(x,-oo,oo))

# %%
expr2=((3*x**6)*sin(5*x))/sqrt(x)-4/3*pi

# %%
expr2

# %%
solve(expr2,x)

# %%
a,b,c=symbols('a b c')

# %%
expr3=a*x**2+b*x+c

# %%
expr3

# %%
solve(expr3,x)

# %%
expr3=pi*x**2-x+3
solve(expr3,x)

# %%
solve(x**4-x-1,x)[0]

# %%
reduce_inequalities([x>=1/x,x<= x**2-1],x)

# %%
sp.plot(sin(x)/x**3,(x,-0.005,0.005))

# %%
plot_implicit(y>x**2)

# %%
from sympy.plotting.plot import plot3d
plot3d(x**2-y,(x,-5,5),(y,-5,5))

# %%
from sympy.plotting.plot import Plot , ContourSeries

# %%
Plot(ContourSeries(sqrt(x**2+y**2),(x,-7,7),(y,-5,5))).show()

# %%
from sympy.plotting import plot3d_parametric_line

# %%
plot3d_parametric_line(cos(x),sin(x),x,(x,-10,10))

# %%
from sympy.plotting import plot3d_parametric_surface

# %%
plot3d_parametric_surface(cos(x+y),sin(x+y),x-y,(x,-10,10),(y,-10,10))
