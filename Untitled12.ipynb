# %%
import pandas as pd

# %%
datos=pd.read_csv('drive/MyDrive/Colab Notebooks/conjunto_de_datos_concentradohogar_enigh_2020_ns.csv')

# %%
datos

# %%
datos2=datos.loc[datos.tam_loc == 2]

# %%
datos2.ing_cor.mean()

# %%
datos2.filter(['ing_cor','gastos'])

# %%
datos.keys().values

# %%
datos2.filter(['ing_cor','gasto_mon'])
